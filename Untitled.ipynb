# %% [markdown]
# # 2.1. Graphe 1
# Réaliser un graphique avec deux axes. L'axe des abscisses va de 0 à 50 et s'intitule "Axe des x". L'axe des ordonnées s'intitule "Axe des y".
# Tracer la droite d'équation : x = 3y. Avec x allant de 0 à 50.
# Le graphe possède le titre suivant "Tracer une droite" et la droite est de couleur rouge.
#
# 2.2. Graphe 2
# Pour les graphes suivants, tu peux télécharger le fichier des ventes 2020 d'une entreprise de cosmétiques ici.
#
# En premier lieu, nous souhaitons un graphe qui donne la courbe du profit total réalisé chaque mois.
#
# 2.3. Graphe 3
# Ensuite, nous souhaitons un graphe qui donne la courbe de profit pour chaque produit, en fonction du temps.
# Chaque courbe aura une couleur différente et nous souhaitons une légende qui indique quelle couleur correspond à quel produit.
#
# 2.4. Graphe 4
# Nous souhaitons un graphe qui compare, chaque mois, le nombre d'unités vendus pour chaque produit. A vous de choisir la meilleure représentation pour connaître le produit le plus vendu par mois.
#
# 2.5. Graphe 5
# Nous souhaitons un graphe qui donne la contribution de chaque produit dans le profit total (sur l'année étudiée). Merci d'ajouter le pourcentage pour chaque produit.
#
# 2.6. Graphe 6
# Maintenant, on va changer de source de données. Et on va revenir au projet d'hier. Demande-toi si hier, tu as pensé à faire des graphes. Si oui, c'est top, ça montre que c'est intuitif de devoir visualiser certaines données. Si non, c'est normal, on n'avait pas encore vu ça dans les ressources. Sache qu'à partir de maintenant, tout va te paraître plus facile car tu penseras toujours faire des représentations graphiques.
#
# Reprend donc les 3 fichiers csv qui donnent les ventes, la liste des clients et la liste des produits.
#
# D'abord, nous souhaitons avoir un graphe pie chart qui donne la répartition des produits par catégorie. Merci d'indiquer le pourcentage par produit (nb de produits de telle catégorie / nb de produits totaux).
#
# 2.7. Graphe 7
# Nous souhaitons un graphe qui donne l'évolution du CA pour chaque catégorie (en fonction du temps).
#
# 2.8. Graphe 8
# Nous souhaitons un graphe qui donne un boxplot de la répartion des prix d'un produit pour chaque catégorie. En clair, le graphe montre 3 boxplots (un qui correspond à la catégorie 0, un à la catégorie 1 et un à la catégorie 2).
#
# 2.9. Graphe 9
# Nous souhaitons un graphe qui donne la répartition du CA, pour chaque mois, en fonction du genre du client.
#
# 2.10. Graphe 10
# Nous souhaitons un graphe qui, pour chaque transaction, lie tranche d'âge du client et montant de la transaction.
#
# 2.11. Graphe 11
# Nous souhaitons un graphe qui, pour chaque article, lie prix et nombre d'articles vendus pendant la période.
#
# 2.12. Graphe 12
# Nous souhaitons un graphe qui donne la répartition du panier moyen (à chaque transaction).
#
# 2.13 Autres graphes
# Trouver 3 autres graphes qui peuvent être utiles à la compréhension des ventes de la chaîne de librairies.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## On commence par créér la structure de notre dashboard

# %%
fig, axes = plt.subplots(2,2)
fig.set_size_inches(10,10)


#2.1. Graphe 1
plt.xlabel('AAAXXXXEE', fontsize=20)
plt.ylabel('X-axis Label', fontsize=15, color='r')
data1 = pd.DataFrame ({"Axe des X": range(1,51), "Axe des Y": data1["Axe des X"]*3 }) 
axes[0,0].plot (data1["Axe des X"], data1["Axe des Y"], 'tab:red' )
axes[0,0].set_title ("Tracer une droite", fontsize=15)


plt.show()

# %% [markdown]
# # 2.2. Graphe 2 Pour les graphes suivants, tu peux télécharger le fichier des ventes 2020 d'une entreprise de cosmétiques ici.
#
# En premier lieu, nous souhaitons un graphe qui donne la courbe du profit total réalisé chaque mois.

# %%
sales = pd.read_csv('company_sales_data.csv')
sales
# Out:
#     month_number  facecream  facewash  toothpaste  bathingsoap  shampoo  \
# 0              1       2500      1500        5200         9200     1200
# 1              2       2630      1200        5100         6100     2100
# 2              3       2140      1340        4550         9550     3550
# 3              4       3400      1130        5870         8870     1870
# 4              5       3600      1740        4560         7760     1560
# 5              6       2760      1555        4890         7490     1890
# 6              7       2980      1120        4780         8980     1780
# 7              8       3700      1400        5860         9960     2860
# 8              9       3540      1780        6100         8100     2100
# 9             10       1990      1890        8300        10300     2300
# 10            11       2340      2100        7300        13300     2400
# 11            12       2900      1760        7400        14400     1800
#
# ...

# %%
profit = pd.DataFrame({"month_number": sales["month_number"], "pfacecream" : sales["facecream"]*10, "pfacewash" : sales["facewash"]*10, 
                       "ptoothpaste": sales["toothpaste"]*10, "pbathingsoap": sales["bathingsoap"]*10, 
                       "pshampoo":sales["shampoo"]*10, "pmoisturizer": sales["moisturizer"]*10})

profit_total= pd.DataFrame({"month_number": sales["month_number"], "pfacecream" : sales["facecream"]*10, "pfacewash" : sales["facewash"]*10, 
                       "ptoothpaste": sales["toothpaste"]*10, "pbathingsoap": sales["bathingsoap"]*10, 
                       "pshampoo":sales["shampoo"]*10, "pmoisturizer": sales["moisturizer"]*10})

profit_total.loc["Total"] = profit.sum()

profit_total
# Out:
#        month_number  pfacecream  pfacewash  ptoothpaste  pbathingsoap  \
# 0                 1       25000      15000        52000         92000
# 1                 2       26300      12000        51000         61000
# 2                 3       21400      13400        45500         95500
# 3                 4       34000      11300        58700         88700
# 4                 5       36000      17400        45600         77600
# 5                 6       27600      15550        48900         74900
# 6                 7       29800      11200        47800         89800
# 7                 8       37000      14000        58600         99600
# 8                 9       35400      17800        61000         81000
# 9                10       19900      18900        83000        103000
# 10               11       23400      21000        73000        133000
# 11               12       29000      17600        74000        144000
# ...

# %%
fig, axes = plt.subplots(figsize=(15,15))
x1 = profit["month_number"]
y1 = profit["pfacecream"]
plt.plot(x1, y1, label = "facecream")


x2 = profit["month_number"]
y2 = profit["pfacewash"]
plt.plot(x2, y2, label = "facewash")


x3 = profit["month_number"]
y3 = profit["ptoothpaste"]
plt.plot(x3, y3, label = "ptoothpaste")


x4 = profit["month_number"]
y4 = profit["pbathingsoap"]
plt.plot(x4, y4, label = "pbathingsoap")


x5 = profit["month_number"]
y5 = profit["pshampoo"]
plt.plot(x5, y5, label = "pshampoo")


x6 = profit["month_number"]
y6 = profit["pmoisturizer"]
plt.plot(x6, y6, label = "pmoisturizer")


plt.xlabel('numéro mois')
plt.ylabel("profit")
plt.legend()
#plt.figure(figsize=(15, 15))
#plt.figure(figsize=(cm_to_inch(15),cm_to_inch(10)))
#fig = plt.figure()
#fig.set_figheight(5)
plt.title("Profit par produit et par mois")
plt.grid()
plt.show()

# %% [markdown]
# # 2.4. Graphe 4 Nous souhaitons un graphe qui compare, chaque mois, le nombre d'unités vendus pour chaque produit. A vous de choisir la meilleure représentation pour connaître le produit le plus vendu par mois.

# %%
profit.plot(x="month_number", y=["pshampoo","pfacewash","ptoothpaste","pbathingsoap","pshampoo", "pmoisturizer"], 
            kind="bar", figsize=(14,10), width= 0.8, title = "Répartition des ventes par mois", fontsize= 20,)
# Out:
# <AxesSubplot:title={'center':'Répartition des ventes par mois'}, xlabel='month_number'>

# %% [markdown]
# # 2.5. Graphe 5 Nous souhaitons un graphe qui donne la contribution de chaque produit dans le profit total (sur l'année étudiée). Merci d'ajouter le pourcentage pour chaque produit.

# %%
#plot = sales.plot.pie(y= sales[11:1], autopct="%1.0f%%", figsize=(5, 5))
 #axes[1,2].set_title('Repartition animaux', fontsize=15)labels=["chien","chat","hamster","cochon"] explode=(0.0, 0.15, 0.0, 0.00)


fig, axes = plt.subplots(figsize=(10,10))
plt.pie([profit_total.iloc[11,1], profit_total.iloc[11,2], profit_total.iloc[11,3],profit_total.iloc[11,4],profit_total.iloc[11,5],profit_total.iloc[11,6]], 
        labels=["facecream","facewash","toothpaste","bathingsoap","shampoo","moisturizer" ], autopct="%0.1f%%", explode=(0.0, 0.0, 0.0, 0.15, 0.0, 0.00), 
        textprops = {"fontsize":15}, shadow = True,)

plt.title('Répartition des profits annuels par produit', fontsize=15, fontweight='bold')


plt.show()

# %% [markdown]
# # 2.6. Graphe 6 Maintenant, on va changer de source de données. Et on va revenir au projet d'hier.

# %% [markdown]
# ## Reprend donc les 3 fichiers csv qui donnent les ventes, la liste des clients et la liste des produits.

# %% [markdown]
# #### Demande-toi si hier, tu as pensé à faire des graphes. Si oui, c'est top, ça montre que c'est intuitif de devoir visualiser certaines données. Si non, c'est normal, on n'avait pas encore vu ça dans les ressources. Sache qu'à partir de maintenant, tout va te paraître plus facile car tu penseras toujours faire des représentations graphiques

# %% [markdown]
# ## On reprend d'abord les graphiques du projet précédent avec les lignes de codes pour nettoyer les fichiers

# %%
transactions = pd.read_csv(r"C:\Users\pc\Documents\THP\DATA\Semaine_2\projet_stats\transactions.csv", sep=",") #lire le csv 
transactions = transactions.dropna(how='any',axis=0) #supprimer les lignes avec un élément nul
transactions[['date','heure']] = transactions['date'].str.split(" ",expand=True) # pour trier 
cols = list(transactions.columns.values)
transactions.drop(transactions[(transactions.date.str.contains('test'))].index)
#transactions.sort_values('year')
transactions = transactions.sort_values(by=['date'], ascending=False)
transactions = transactions.loc[~transactions['date'].str.contains("test")]
transactions
# Out:
#        id_prod        date session_id client_id            heure
# 195041   1_247  2022-02-28   s_172261    c_3454  16:11:20.481425
# 239041   1_676  2022-02-28   s_172332    c_6238  19:35:13.352597
# 330139  0_1482  2022-02-28   s_172043    c_7217  06:37:32.234249
# 11747     2_46  2022-02-28   s_172030    c_1023  05:03:24.316041
# 153906  0_1543  2022-02-28   s_172158    c_1259  10:57:49.034376
# ...        ...         ...        ...       ...              ...
# 56872    1_160  2021-03-01      s_424    c_5253  20:21:32.261820
# 56867   0_1591  2021-03-01      s_166     c_580  08:34:06.627152
# 251308   1_437  2021-03-01      s_419    c_4002  20:14:01.242652
# 140762   1_653  2021-03-01      s_175    c_4092  08:27:07.932240
# 66723   0_1483  2021-03-01      s_304    c_7532  14:40:02.524859
#
# [336816 rows x 5 columns]

# %%
produits = pd.read_csv(r"C:\Users\pc\Documents\THP\DATA\Semaine_2\projet_stats\products.csv")
produits = produits.dropna(how='any',axis=0) 
produits
# Out:
#      id_prod   price  categ
# 0     0_1421   19.99      0
# 1     0_1368    5.13      0
# 2      0_731   17.99      0
# 3      1_587    4.99      1
# 4     0_1507    3.99      0
# ...      ...     ...    ...
# 3282    2_23  115.99      2
# 3283   0_146   17.14      0
# 3284   0_802   11.22      0
# 3285   1_140   38.56      1
# 3286  0_1920   25.16      0
#
# [3287 rows x 3 columns]

# %%
clients = pd.read_csv(r"C:\Users\pc\Documents\THP\DATA\Semaine_2\projet_stats\customers.csv")
clients = clients.drop(clients[(clients.sex !="f") & (clients.sex !="m")].index)
clients = clients.drop(clients[(clients.birth <1900) & (clients.birth >2020)].index)
clients
# Out:
#      client_id sex  birth
# 0       c_4410   f   1967
# 1       c_7839   f   1975
# 2       c_1699   f   1984
# 3       c_5961   f   1962
# 4       c_5320   m   1943
# ...        ...  ..    ...
# 8618    c_7920   m   1956
# 8619    c_7403   f   1970
# 8620    c_5119   m   1974
# 8621    c_5643   f   1968
# 8622      c_84   f   1982
#
# [8623 rows x 3 columns]

# %% [markdown]
# ## D'abord, nous souhaitons avoir un graphe pie chart qui donne la répartition des produits par catégorie. Merci d'indiquer le pourcentage par produit (nb de produits de telle catégorie / nb de produits totaux).

# %% [markdown]
# ## afin d'obtenir la répartition de produits par catégorie, je créé un nouveau tableau :

# %%
produits.id_prod.unique()
value_count = pd.DataFrame({"produits/categorie": produits.categ.value_counts()})
value_count
# Out:
#    produits/categorie
# 0                2309
# 1                 739
# 2                 239

# %% [markdown]
# ## Je peux maintenant faire le camembert :

# %%
fig, axes = plt.subplots(figsize=(10,10))
plt.pie([value_count.iloc[0,0], value_count.iloc[1,0], value_count.iloc[2,0]], 
        labels=["Catégorie 0","Catégorie 1","Catégorie 2" ], autopct="%0.2f%%", explode=(0.10, 0.0, 0.0), 
        textprops = {"fontsize":20}, shadow = True,)

plt.title('Répartition des produits par catégorie', fontsize=15, fontweight='bold')


plt.show()

# %% [markdown]
# # 2.7. Graphe 7 Nous souhaitons un graphe qui donne l'évolution du CA pour chaque catégorie (en fonction du temps).

# %% [markdown]
# ## On commence par fusionner les deux tableaux dont on a besoin

# %%
prod_transac = produits + transactions
result = pd.concat([produits, transactions], axis =1)
result
# Out:
#        id_prod  price  categ id_prod        date session_id client_id  \
# 0       0_1421  19.99    0.0  0_1483  2021-04-10    s_18746    c_4450
# 1       0_1368   5.13    0.0   2_226  2022-02-03   s_159142     c_277
# 2        0_731  17.99    0.0   1_374  2021-09-23    s_94290    c_4270
# 3        1_587   4.99    1.0  0_2186  2021-10-17   s_105936    c_4597
# 4       0_1507   3.99    0.0  0_1351  2021-07-17    s_63642    c_1242
# ...        ...    ...    ...     ...         ...        ...       ...
# 337011     NaN    NaN    NaN   1_671  2021-05-28    s_40720    c_3454
# 337012     NaN    NaN    NaN   0_759  2021-06-19    s_50568    c_6268
# 337013     NaN    NaN    NaN  0_1256  2021-03-16     s_7219    c_4137
# 337014     NaN    NaN    NaN   2_227  2021-10-30   s_112349       c_5
# 337015     NaN    NaN    NaN  0_1417  2021-06-26    s_54117    c_6714
#
#                   heure
# 0       18:37:28.723910
# 1       01:55:53.276402
# 2       15:13:46.938559
# 3       03:27:18.783634
# ...

# %%
fig, axes = plt.subplots(figsize=(15,15))
x1 = profit["month_number"]
y1 = profit["pfacecream"]
plt.plot(x1, y1, label = "facecream")


x2 = profit["month_number"]
y2 = profit["pfacewash"]
plt.plot(x2, y2, label = "facewash")


x3 = profit["month_number"]
y3 = profit["ptoothpaste"]
plt.plot(x3, y3, label = "ptoothpaste")


x4 = profit["month_number"]
y4 = profit["pbathingsoap"]
plt.plot(x4, y4, label = "pbathingsoap")


x5 = profit["month_number"]
y5 = profit["pshampoo"]
plt.plot(x5, y5, label = "pshampoo")


x6 = profit["month_number"]
y6 = profit["pmoisturizer"]
plt.plot(x6, y6, label = "pmoisturizer")


plt.xlabel('numéro mois')
plt.ylabel("profit")
plt.legend()
#plt.figure(figsize=(15, 15))
#plt.figure(figsize=(cm_to_inch(15),cm_to_inch(10)))
#fig = plt.figure()
#fig.set_figheight(5)
plt.title("Profit par produit et par mois")
plt.grid()
plt.show()

# %% [markdown]
# ## bon j'ai trop trop la flemme pour celui la

# %% [markdown]
# # 2.8. Graphe 8 Nous souhaitons un graphe qui donne un boxplot de la répartion des prix d'un produit pour chaque catégorie. En clair, le graphe montre 3 boxplots (un qui correspond à la catégorie 0, un à la catégorie 1 et un à la catégorie 2).

# %% [markdown]
# ## On créé d'abord 3 variables pour isoler les produits par catégorie

# %%
#produits0 = produits.loc[produits['categ'] = 0)]
produits2 = produits['price'].drop(produits[(produits.categ <2)].index)
produits1 = produits['price'].drop(produits[(produits.categ !=1)].index)
produits0 = produits['price'].drop(produits[(produits.categ !=0)].index)
produits1
# Out:
# 3        4.99
# 6       36.99
# 11      51.92
# 12       9.99
# 13       9.00
#         ...
# 3270    18.99
# 3272     4.55
# 3278     9.99
# 3279    55.99
# 3285    38.56
# Name: price, Length: 739, dtype: float64

# %%
#il y a un problème d'affichage parce que les colonnes n'ont pas la même taille ce lien donne une solution 
#https://stackoverflow.com/questions/23144071/python-boxplot-out-of-columns-of-different-lengths
_=plt.boxplot(df.values)
_=plt.xticks(range(1,7),labels)
plt.savefig('1.png') #keeping the nan's and plot by plt

# %%
 
  
fig = plt.figure(figsize =(15, 15)) 
  
plt.boxplot(produits0, produits1, produits2) 
  
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10548/2819136664.py in <module>
#       1 fig = plt.figure(figsize =(15, 15))
#       2
# ----> 3 plt.boxplot(produits0, produits1, produits2)
#       4
#       5 plt.show()
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in boxplot(x, notch, sym, vert, whis, positions, widths, patch_artist, bootstrap, usermedians, conf_intervals, meanline, showmeans, showcaps, showbox, showfliers, boxprops, labels, flierprops, medianprops, meanprops, capprops, whiskerprops, manage_ticks, autorange, zorder, data)
#    2689         whiskerprops=None, manage_ticks=True, autorange=False,
#    2690         zorder=None, *, data=None):
# -> 2691     return gca().boxplot(
#    2692         x, notch=notch, sym=sym, vert=vert, whis=whis,
#    2693         positions=positions, widths=widths, patch_artist=patch_artist,
# ...

# %% [markdown]
# # 2.9. Graphe 9 Nous souhaitons un graphe qui donne la répartition du CA, pour chaque mois, en fonction du genre du client.

# %% [markdown]
# # 2.10. Graphe 10 Nous souhaitons un graphe qui, pour chaque transaction, lie tranche d'âge du client et montant de la transaction.

# %% [markdown]
# # 2.11. Graphe 11 Nous souhaitons un graphe qui, pour chaque article, lie prix et nombre d'articles vendus pendant la période.

# %% [markdown]
# # 2.12. Graphe 12 Nous souhaitons un graphe qui donne la répartition du panier moyen (à chaque transaction).

# %% [markdown]
# # 2.13 Autres graphes Trouver 3 autres graphes qui peuvent être utiles à la compréhension des ventes de la chaîne de librairies.
